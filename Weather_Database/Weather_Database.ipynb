# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | esperance
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | kulhudhuffushi
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | corinto
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | kovur
# Processing Record 14 of Set 1 | tazovskiy
# Processing Record 15 of Set 1 | kadoshkino
# Processing Record 16 of Set 1 | mogadishu
# Processing Record 17 of Set 1 | port-de-paix
# City not found. Skipping...
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | andenes
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | montorio al vomano
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | inuvik
# Processing Record 25 of Set 1 | shahrud
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | krasnoarmeysk
# Processing Record 28 of Set 1 | san patricio
# Processing Record 29 of Set 1 | hof
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | port hardy
# Processing Record 38 of Set 1 | vestmannaeyjar
# Processing Record 39 of Set 1 | maragogi
# Processing Record 40 of Set 1 | esso
# Processing Record 41 of Set 1 | vanimo
# Processing Record 42 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 1 | lavumisa
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | devonport
# Processing Record 46 of Set 1 | coquimbo
# Processing Record 47 of Set 1 | isangel
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | bathsheba
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | hovd
# Processing Record 2 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 2 | nioro
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | valparaiso
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | mareeba
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | pemba
# Processing Record 12 of Set 2 | geraldton
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | ketchikan
# Processing Record 19 of Set 2 | touros
# Processing Record 20 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 2 | chicama
# Processing Record 22 of Set 2 | oshkosh
# Processing Record 23 of Set 2 | dingle
# Processing Record 24 of Set 2 | tocopilla
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | punta arenas
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | nedryhayliv
# Processing Record 29 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 2 | vila velha
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | prince rupert
# Processing Record 33 of Set 2 | imbituba
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | chernaya kholunitsa
# Processing Record 36 of Set 2 | namatanai
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | inhambane
# Processing Record 39 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | ilulissat
# Processing Record 44 of Set 2 | umm lajj
# Processing Record 45 of Set 2 | camabatela
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | chokurdakh
# Processing Record 48 of Set 2 | manzil tamim
# City not found. Skipping...
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | catabola
# Processing Record 2 of Set 3 | pringsewu
# Processing Record 3 of Set 3 | laranjeiras do sul
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | njombe
# Processing Record 7 of Set 3 | fortuna
# Processing Record 8 of Set 3 | vila
# Processing Record 9 of Set 3 | zabol
# Processing Record 10 of Set 3 | chany
# Processing Record 11 of Set 3 | ulaangom
# Processing Record 12 of Set 3 | marzuq
# Processing Record 13 of Set 3 | mandurah
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | bintulu
# Processing Record 16 of Set 3 | nara
# Processing Record 17 of Set 3 | lasa
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | sechura
# Processing Record 20 of Set 3 | bahir dar
# Processing Record 21 of Set 3 | zdvinsk
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | mayya
# Processing Record 24 of Set 3 | maues
# Processing Record 25 of Set 3 | markova
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | namikupa
# Processing Record 28 of Set 3 | poum
# Processing Record 29 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 3 | yushan
# Processing Record 31 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 32 of Set 3 | monte plata
# Processing Record 33 of Set 3 | acapulco
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | boa vista
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | kamuli
# Processing Record 38 of Set 3 | port blair
# Processing Record 39 of Set 3 | victor harbor
# Processing Record 40 of Set 3 | molteno
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | bandundu
# Processing Record 43 of Set 3 | haines junction
# Processing Record 44 of Set 3 | lubango
# Processing Record 45 of Set 3 | college
# Processing Record 46 of Set 3 | cape town
# Processing Record 47 of Set 3 | kahului
# Processing Record 48 of Set 3 | barcelona
# Processing Record 49 of Set 3 | kaeo
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | oktyabrskoye
# Processing Record 3 of Set 4 | sahrak
# City not found. Skipping...
# Processing Record 4 of Set 4 | villafranca di verona
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | kyren
# Processing Record 7 of Set 4 | verkhnyaya inta
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | skorodnoye
# Processing Record 10 of Set 4 | yulara
# Processing Record 11 of Set 4 | talnakh
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | roding
# Processing Record 14 of Set 4 | tigil
# Processing Record 15 of Set 4 | mabaruma
# Processing Record 16 of Set 4 | umm kaddadah
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 19 of Set 4 | nyurba
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | athens
# Processing Record 22 of Set 4 | barrow
# Processing Record 23 of Set 4 | ostuni
# Processing Record 24 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 4 | dunmore east
# Processing Record 27 of Set 4 | moncao
# Processing Record 28 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 4 | opole
# Processing Record 31 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 32 of Set 4 | xining
# Processing Record 33 of Set 4 | nanortalik
# Processing Record 34 of Set 4 | port lincoln
# Processing Record 35 of Set 4 | pitimbu
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | rio gallegos
# Processing Record 38 of Set 4 | mangai
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | hilo
# Processing Record 41 of Set 4 | arsenyev
# Processing Record 42 of Set 4 | bengkulu
# Processing Record 43 of Set 4 | viedma
# Processing Record 44 of Set 4 | port macquarie
# Processing Record 45 of Set 4 | gat
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | hammond
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | mago
# Processing Record 2 of Set 5 | am timan
# Processing Record 3 of Set 5 | kloulklubed
# Processing Record 4 of Set 5 | luderitz
# Processing Record 5 of Set 5 | tygda
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | vostok
# Processing Record 8 of Set 5 | ribeira grande
# Processing Record 9 of Set 5 | oistins
# Processing Record 10 of Set 5 | shache
# Processing Record 11 of Set 5 | sabzevar
# Processing Record 12 of Set 5 | ostrovnoy
# Processing Record 13 of Set 5 | pundaguitan
# Processing Record 14 of Set 5 | kysyl-syr
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | chimbote
# Processing Record 17 of Set 5 | takab
# Processing Record 18 of Set 5 | burriana
# Processing Record 19 of Set 5 | zabid
# Processing Record 20 of Set 5 | mahajanga
# Processing Record 21 of Set 5 | rio grande
# Processing Record 22 of Set 5 | brae
# Processing Record 23 of Set 5 | kiama
# Processing Record 24 of Set 5 | nelson bay
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | springbok
# Processing Record 28 of Set 5 | castro
# Processing Record 29 of Set 5 | youkounkoun
# Processing Record 30 of Set 5 | hermosillo
# Processing Record 31 of Set 5 | high level
# Processing Record 32 of Set 5 | bodden town
# Processing Record 33 of Set 5 | nikolskoye
# Processing Record 34 of Set 5 | margate
# Processing Record 35 of Set 5 | vao
# Processing Record 36 of Set 5 | hamilton
# Processing Record 37 of Set 5 | sharjah
# Processing Record 38 of Set 5 | karratha
# Processing Record 39 of Set 5 | constitucion
# Processing Record 40 of Set 5 | cherskiy
# Processing Record 41 of Set 5 | sioux lookout
# Processing Record 42 of Set 5 | shelburne
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | ambilobe
# Processing Record 45 of Set 5 | sembakung
# Processing Record 46 of Set 5 | kisangani
# Processing Record 47 of Set 5 | yumen
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | kargasok
# Processing Record 1 of Set 6 | lorengau
# Processing Record 2 of Set 6 | caravelas
# Processing Record 3 of Set 6 | santiago del estero
# Processing Record 4 of Set 6 | xapuri
# Processing Record 5 of Set 6 | santa maria
# Processing Record 6 of Set 6 | ahipara
# Processing Record 7 of Set 6 | east london
# Processing Record 8 of Set 6 | sayyan
# Processing Record 9 of Set 6 | namibe
# Processing Record 10 of Set 6 | hue
# Processing Record 11 of Set 6 | zhuhai
# Processing Record 12 of Set 6 | san juan
# Processing Record 13 of Set 6 | ilebo
# Processing Record 14 of Set 6 | taitung
# Processing Record 15 of Set 6 | saint george
# Processing Record 16 of Set 6 | norrtalje
# Processing Record 17 of Set 6 | kautokeino
# Processing Record 18 of Set 6 | saskylakh
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | staryy krym
# Processing Record 21 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 22 of Set 6 | anan
# Processing Record 23 of Set 6 | ponta do sol
# Processing Record 24 of Set 6 | paragominas
# Processing Record 25 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 6 | gasa
# Processing Record 27 of Set 6 | leningradskiy
# Processing Record 28 of Set 6 | warsaw
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | sao paulo de olivenca
# Processing Record 31 of Set 6 | mbandaka
# Processing Record 32 of Set 6 | majene
# Processing Record 33 of Set 6 | taksimo
# Processing Record 34 of Set 6 | pontalina
# Processing Record 35 of Set 6 | port augusta
# Processing Record 36 of Set 6 | crixas
# Processing Record 37 of Set 6 | avera
# Processing Record 38 of Set 6 | san marcos
# Processing Record 39 of Set 6 | wieliczka
# Processing Record 40 of Set 6 | scalloway
# City not found. Skipping...
# Processing Record 41 of Set 6 | mwense
# Processing Record 42 of Set 6 | matagami
# Processing Record 43 of Set 6 | tulle
# Processing Record 44 of Set 6 | christchurch
# Processing Record 45 of Set 6 | lukovetskiy
# Processing Record 46 of Set 6 | tomatlan
# Processing Record 47 of Set 6 | matara
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | chapais
# Processing Record 50 of Set 6 | sola
# Processing Record 1 of Set 7 | jalu
# Processing Record 2 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 7 | tchibanga
# Processing Record 4 of Set 7 | santiago de cao
# Processing Record 5 of Set 7 | malynivka
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | wajima
# Processing Record 8 of Set 7 | sinnamary
# Processing Record 9 of Set 7 | dauriya
# Processing Record 10 of Set 7 | darhan
# Processing Record 11 of Set 7 | tual
# Processing Record 12 of Set 7 | belyy yar
# Processing Record 13 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | canon city
# Processing Record 17 of Set 7 | olafsvik
# Processing Record 18 of Set 7 | necochea
# Processing Record 19 of Set 7 | lata
# Processing Record 20 of Set 7 | noumea
# Processing Record 21 of Set 7 | pyshma
# Processing Record 22 of Set 7 | cardoso
# Processing Record 23 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 7 | pervomayskiy
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | broome
# Processing Record 27 of Set 7 | te anau
# Processing Record 28 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 7 | aklavik
# Processing Record 30 of Set 7 | winnemucca
# Processing Record 31 of Set 7 | asau
# Processing Record 32 of Set 7 | chepen
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | cap malheureux
# Processing Record 35 of Set 7 | gamba
# Processing Record 36 of Set 7 | vitre
# Processing Record 37 of Set 7 | jantianon
# Processing Record 38 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 7 | kerman
# Processing Record 40 of Set 7 | marsa matruh
# Processing Record 41 of Set 7 | tabuk
# Processing Record 42 of Set 7 | collie
# Processing Record 43 of Set 7 | mecca
# Processing Record 44 of Set 7 | villarrobledo
# Processing Record 45 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 7 | abong mbang
# Processing Record 47 of Set 7 | angoche
# Processing Record 48 of Set 7 | anadyr
# Processing Record 49 of Set 7 | takoradi
# Processing Record 50 of Set 7 | ferkessedougou
# Processing Record 1 of Set 8 | puri
# Processing Record 2 of Set 8 | luganville
# Processing Record 3 of Set 8 | alyangula
# Processing Record 4 of Set 8 | ulladulla
# Processing Record 5 of Set 8 | bulancak
# Processing Record 6 of Set 8 | watertown
# Processing Record 7 of Set 8 | hyeres
# Processing Record 8 of Set 8 | cockburn town
# Processing Record 9 of Set 8 | tromso
# Processing Record 10 of Set 8 | dzitbalche
# Processing Record 11 of Set 8 | medina del campo
# Processing Record 12 of Set 8 | ocampo
# Processing Record 13 of Set 8 | northam
# Processing Record 14 of Set 8 | rakitnoye
# Processing Record 15 of Set 8 | ust-uda
# Processing Record 16 of Set 8 | barinas
# Processing Record 17 of Set 8 | kamenka
# Processing Record 18 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 8 | provideniya
# Processing Record 20 of Set 8 | miracema do tocantins
# Processing Record 21 of Set 8 | kilindoni
# Processing Record 22 of Set 8 | bilibino
# Processing Record 23 of Set 8 | caxito
# Processing Record 24 of Set 8 | praya
# Processing Record 25 of Set 8 | hofn
# Processing Record 26 of Set 8 | nemuro
# Processing Record 27 of Set 8 | raha
# Processing Record 28 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 8 | moss vale
# Processing Record 30 of Set 8 | tungor
# Processing Record 31 of Set 8 | ternuvate
# Processing Record 32 of Set 8 | sabha
# Processing Record 33 of Set 8 | el alto
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 35 of Set 8 | lluta
# Processing Record 36 of Set 8 | honiara
# Processing Record 37 of Set 8 | nantucket
# Processing Record 38 of Set 8 | seymchan
# Processing Record 39 of Set 8 | koppies
# Processing Record 40 of Set 8 | inirida
# Processing Record 41 of Set 8 | ayorou
# Processing Record 42 of Set 8 | launceston
# Processing Record 43 of Set 8 | omsukchan
# Processing Record 44 of Set 8 | kalashnikovo
# Processing Record 45 of Set 8 | dawei
# Processing Record 46 of Set 8 | lingdong
# Processing Record 47 of Set 8 | kiunga
# Processing Record 48 of Set 8 | prainha
# Processing Record 49 of Set 8 | coihaique
# Processing Record 50 of Set 8 | sulangan
# Processing Record 1 of Set 9 | tombouctou
# Processing Record 2 of Set 9 | havre-saint-pierre
# Processing Record 3 of Set 9 | blyth
# Processing Record 4 of Set 9 | codrington
# Processing Record 5 of Set 9 | pascagoula
# Processing Record 6 of Set 9 | atar
# Processing Record 7 of Set 9 | zhanaozen
# Processing Record 8 of Set 9 | darnah
# Processing Record 9 of Set 9 | dehloran
# Processing Record 10 of Set 9 | batouri
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | kathmandu
# Processing Record 13 of Set 9 | maniitsoq
# Processing Record 14 of Set 9 | makokou
# Processing Record 15 of Set 9 | madang
# Processing Record 16 of Set 9 | miri
# Processing Record 17 of Set 9 | blagoyevo
# Processing Record 18 of Set 9 | bandarbeyla
# Processing Record 19 of Set 9 | sambava
# Processing Record 20 of Set 9 | coos bay
# Processing Record 21 of Set 9 | matiguas
# Processing Record 22 of Set 9 | coruripe
# Processing Record 23 of Set 9 | hecun
# Processing Record 24 of Set 9 | airai
# Processing Record 25 of Set 9 | mitu
# Processing Record 26 of Set 9 | moerai
# Processing Record 27 of Set 9 | orumiyeh
# Processing Record 28 of Set 9 | kondoa
# Processing Record 29 of Set 9 | grand gaube
# Processing Record 30 of Set 9 | hobyo
# Processing Record 31 of Set 9 | gizo
# Processing Record 32 of Set 9 | arlit
# Processing Record 33 of Set 9 | methoni
# Processing Record 34 of Set 9 | teahupoo
# Processing Record 35 of Set 9 | the valley
# Processing Record 36 of Set 9 | teya
# Processing Record 37 of Set 9 | karatau
# Processing Record 38 of Set 9 | araouane
# Processing Record 39 of Set 9 | saldanha
# Processing Record 40 of Set 9 | korla
# Processing Record 41 of Set 9 | belawan
# Processing Record 42 of Set 9 | agadez
# Processing Record 43 of Set 9 | itaituba
# Processing Record 44 of Set 9 | los chiles
# Processing Record 45 of Set 9 | raglan
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | ozimek
# Processing Record 48 of Set 9 | gorontalo
# Processing Record 49 of Set 9 | la ronge
# Processing Record 50 of Set 9 | manokwari
# Processing Record 1 of Set 10 | tabas
# Processing Record 2 of Set 10 | cochrane
# Processing Record 3 of Set 10 | kyabe
# Processing Record 4 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 10 | udachnyy
# Processing Record 6 of Set 10 | bonavista
# Processing Record 7 of Set 10 | kumluca
# Processing Record 8 of Set 10 | shebunino
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | lixourion
# Processing Record 11 of Set 10 | najran
# Processing Record 12 of Set 10 | rabo de peixe
# Processing Record 13 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 10 | at-bashi
# Processing Record 15 of Set 10 | palestine
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | vila franca do campo
# Processing Record 18 of Set 10 | carinhanha
# Processing Record 19 of Set 10 | vallenar
# Processing Record 20 of Set 10 | chippewa falls
# Processing Record 21 of Set 10 | agadir
# Processing Record 22 of Set 10 | binga
# Processing Record 23 of Set 10 | poronaysk
# Processing Record 24 of Set 10 | puerto carreno
# Processing Record 25 of Set 10 | saint-michel-des-saints
# Processing Record 26 of Set 10 | sao francisco de paula
# Processing Record 27 of Set 10 | mount isa
# Processing Record 28 of Set 10 | zhezkazgan
# Processing Record 29 of Set 10 | kandrian
# Processing Record 30 of Set 10 | varde
# Processing Record 31 of Set 10 | kerema
# Processing Record 32 of Set 10 | rocha
# Processing Record 33 of Set 10 | harrogate
# Processing Record 34 of Set 10 | tabou
# Processing Record 35 of Set 10 | nome
# Processing Record 36 of Set 10 | lagoa
# Processing Record 37 of Set 10 | lethem
# Processing Record 38 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 39 of Set 10 | westport
# Processing Record 40 of Set 10 | arica
# Processing Record 41 of Set 10 | ambulu
# Processing Record 42 of Set 10 | faranah
# Processing Record 43 of Set 10 | srednekolymsk
# Processing Record 44 of Set 10 | juneau
# Processing Record 45 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 10 | makueni
# Processing Record 47 of Set 10 | mugur-aksy
# Processing Record 48 of Set 10 | kropotkin
# Processing Record 49 of Set 10 | lensk
# Processing Record 50 of Set 10 | pimentel
# Processing Record 1 of Set 11 | norman wells
# Processing Record 2 of Set 11 | minab
# Processing Record 3 of Set 11 | sidi qasim
# City not found. Skipping...
# Processing Record 4 of Set 11 | barranca
# Processing Record 5 of Set 11 | neiafu
# Processing Record 6 of Set 11 | santa vitoria do palmar
# Processing Record 7 of Set 11 | awbari
# Processing Record 8 of Set 11 | taoudenni
# Processing Record 9 of Set 11 | farah
# Processing Record 10 of Set 11 | zhaotong
# Processing Record 11 of Set 11 | oakham
# Processing Record 12 of Set 11 | roald
# Processing Record 13 of Set 11 | talawdi
# City not found. Skipping...
# Processing Record 14 of Set 11 | harper
# Processing Record 15 of Set 11 | copiapo
# Processing Record 16 of Set 11 | pokhara
# Processing Record 17 of Set 11 | taman
# Processing Record 18 of Set 11 | vista hermosa
# Processing Record 19 of Set 11 | marystown
# Processing Record 20 of Set 11 | misratah
# Processing Record 21 of Set 11 | erenhot
# Processing Record 22 of Set 11 | beringovskiy
# Processing Record 23 of Set 11 | lac-megantic
# Processing Record 24 of Set 11 | along
# Processing Record 25 of Set 11 | peace river
# Processing Record 26 of Set 11 | ruteng
# Processing Record 27 of Set 11 | san clemente
# Processing Record 28 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 29 of Set 11 | khawhai
# Processing Record 30 of Set 11 | vestmanna
# Processing Record 31 of Set 11 | ziro
# Processing Record 32 of Set 11 | khingansk
# Processing Record 33 of Set 11 | yamada
# Processing Record 34 of Set 11 | hinganghat
# Processing Record 35 of Set 11 | padang
# Processing Record 36 of Set 11 | ayame
# Processing Record 37 of Set 11 | genhe
# Processing Record 38 of Set 11 | kunstat
# Processing Record 39 of Set 11 | mendi
# Processing Record 40 of Set 11 | deputatskiy
# Processing Record 41 of Set 11 | surt
# Processing Record 42 of Set 11 | teguldet
# Processing Record 43 of Set 11 | kargalinskaya
# Processing Record 44 of Set 11 | aksha
# Processing Record 45 of Set 11 | zvishavane
# Processing Record 46 of Set 11 | nanakuli
# Processing Record 47 of Set 11 | sarankhola
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | dalianwan
# Processing Record 50 of Set 11 | belaya gora
# Processing Record 1 of Set 12 | makubetsu
# Processing Record 2 of Set 12 | saint-pierre
# Processing Record 3 of Set 12 | nichinan
# Processing Record 4 of Set 12 | laguna
# Processing Record 5 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 6 of Set 12 | saint-augustin
# Processing Record 7 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 12 | chino valley
# Processing Record 9 of Set 12 | vengerovo
# Processing Record 10 of Set 12 | rexburg
# Processing Record 11 of Set 12 | innisfail
# Processing Record 12 of Set 12 | chernyshevskiy
# Processing Record 13 of Set 12 | lakatoro
# Processing Record 14 of Set 12 | roswell
# Processing Record 15 of Set 12 | yar-sale
# Processing Record 16 of Set 12 | sao jose da coroa grande
# Processing Record 17 of Set 12 | sistranda
# Processing Record 18 of Set 12 | faya
# Processing Record 19 of Set 12 | tura
# Processing Record 20 of Set 12 | urumqi
# Processing Record 21 of Set 12 | alexandria
# Processing Record 22 of Set 12 | nan
# Processing Record 23 of Set 12 | vila do maio
# Processing Record 24 of Set 12 | chongwe
# Processing Record 25 of Set 12 | akureyri
# Processing Record 26 of Set 12 | nishihara
# Processing Record 27 of Set 12 | hervey bay
# Processing Record 28 of Set 12 | xam nua
# Processing Record 29 of Set 12 | sabang
# Processing Record 30 of Set 12 | homer
# Processing Record 31 of Set 12 | shimoda
# Processing Record 32 of Set 12 | tambura
# Processing Record 33 of Set 12 | sinop
# Processing Record 34 of Set 12 | kaitangata
# Processing Record 35 of Set 12 | santa cruz del sur
# Processing Record 36 of Set 12 | merrill
# Processing Record 37 of Set 12 | san quintin
# Processing Record 38 of Set 12 | sfantu gheorghe
# Processing Record 39 of Set 12 | longyearbyen
# Processing Record 40 of Set 12 | fukue
# Processing Record 41 of Set 12 | baruun-urt
# Processing Record 42 of Set 12 | puerto quijarro
# Processing Record 43 of Set 12 | derzhavinsk
# Processing Record 44 of Set 12 | omboue
# Processing Record 45 of Set 12 | sangar
# Processing Record 46 of Set 12 | aykhal
# Processing Record 47 of Set 12 | schaffhausen
# Processing Record 48 of Set 12 | buenos aires
# Processing Record 49 of Set 12 | los llanos de aridane
# Processing Record 50 of Set 12 | manggar
# Processing Record 1 of Set 13 | pangnirtung
# Processing Record 2 of Set 13 | magadan
# Processing Record 3 of Set 13 | dhidhdhoo
# Processing Record 4 of Set 13 | manzanillo
# Processing Record 5 of Set 13 | uarini
# Processing Record 6 of Set 13 | san cristobal
# Processing Record 7 of Set 13 | riyadh
# Processing Record 8 of Set 13 | itubera
# Processing Record 9 of Set 13 | fort saint james
# Processing Record 10 of Set 13 | elban
# Processing Record 11 of Set 13 | kokoda
# Processing Record 12 of Set 13 | akdagmadeni
# Processing Record 13 of Set 13 | hambantota
# Processing Record 14 of Set 13 | zasheyek
# Processing Record 15 of Set 13 | itaporanga
# Processing Record 16 of Set 13 | seoul
# Processing Record 17 of Set 13 | wonthaggi
# Processing Record 18 of Set 13 | escanaba
# Processing Record 19 of Set 13 | venkatagiri
# Processing Record 20 of Set 13 | mayumba
# Processing Record 21 of Set 13 | bongor
# Processing Record 22 of Set 13 | honjo
# Processing Record 23 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 13 | puerto narino
# Processing Record 25 of Set 13 | fort nelson
# Processing Record 26 of Set 13 | springdale
# Processing Record 27 of Set 13 | qaqortoq
# Processing Record 28 of Set 13 | savinskiy
# Processing Record 29 of Set 13 | west bay
# Processing Record 30 of Set 13 | manturovo
# Processing Record 31 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 32 of Set 13 | mayor pablo lagerenza
# Processing Record 33 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 13 | semey
# Processing Record 35 of Set 13 | tautira
# Processing Record 36 of Set 13 | pevek
# Processing Record 37 of Set 13 | pacific grove
# Processing Record 38 of Set 13 | kharitonovo
# Processing Record 39 of Set 13 | toora-khem
# Processing Record 40 of Set 13 | klerksdorp
# Processing Record 41 of Set 13 | ormond beach
# Processing Record 42 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 13 | pirsagi
# City not found. Skipping...
# Processing Record 44 of Set 13 | doha
# Processing Record 45 of Set 13 | perpignan
# Processing Record 46 of Set 13 | kapit
# Processing Record 47 of Set 13 | aviles
# Processing Record 48 of Set 13 | pangkalanbuun
# Processing Record 49 of Set 13 | hami
# Processing Record 50 of Set 13 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 14 | north bend
# Processing Record 2 of Set 14 | lidkoping
# Processing Record 3 of Set 14 | bazarnyy syzgan
# Processing Record 4 of Set 14 | yerbogachen
# Processing Record 5 of Set 14 | potosi
# Processing Record 6 of Set 14 | kragujevac
# Processing Record 7 of Set 14 | puerto asis
# Processing Record 8 of Set 14 | nakambala
# Processing Record 9 of Set 14 | mount gambier
# Processing Record 10 of Set 14 | harer
# Processing Record 11 of Set 14 | pisco
# Processing Record 12 of Set 14 | shingu
# Processing Record 13 of Set 14 | baherden
# Processing Record 14 of Set 14 | ayios matthaios
# City not found. Skipping...
# Processing Record 15 of Set 14 | halkirk
# Processing Record 16 of Set 14 | khuzdar
# Processing Record 17 of Set 14 | kalnibolotskaya
# Processing Record 18 of Set 14 | neuquen
# Processing Record 19 of Set 14 | broken hill
# Processing Record 20 of Set 14 | nadym
# Processing Record 21 of Set 14 | lavrentiya
# Processing Record 22 of Set 14 | tiarei
# Processing Record 23 of Set 14 | bitung
# Processing Record 24 of Set 14 | palafrugell
# Processing Record 25 of Set 14 | bozova
# Processing Record 26 of Set 14 | komyshnya
# Processing Record 27 of Set 14 | fare
# Processing Record 28 of Set 14 | kruisfontein
# Processing Record 29 of Set 14 | troyes
# Processing Record 30 of Set 14 | shitanjing
# Processing Record 31 of Set 14 | pucallpa
# Processing Record 32 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 33 of Set 14 | callaguip
# Processing Record 34 of Set 14 | burica
# City not found. Skipping...
# Processing Record 35 of Set 14 | portland
# Processing Record 36 of Set 14 | aranos
# Processing Record 37 of Set 14 | salalah
# Processing Record 38 of Set 14 | jinxiang
# Processing Record 39 of Set 14 | bosaso
# Processing Record 40 of Set 14 | villars-sur-glane
# Processing Record 41 of Set 14 | hualmay
# Processing Record 42 of Set 14 | ixtapa
# Processing Record 43 of Set 14 | alor setar
# Processing Record 44 of Set 14 | poshekhonye
# Processing Record 45 of Set 14 | mandiana
# Processing Record 46 of Set 14 | hornepayne
# Processing Record 47 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 14 | bambanglipuro
# Processing Record 49 of Set 14 | palembang
# Processing Record 50 of Set 14 | jega
# Processing Record 1 of Set 15 | nevelsk
# Processing Record 2 of Set 15 | dovbysh
# Processing Record 3 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 15 | dasoguz
# Processing Record 5 of Set 15 | kyshtovka
# Processing Record 6 of Set 15 | bulgan
# Processing Record 7 of Set 15 | normandin
# Processing Record 8 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 15 | oksfjord
# Processing Record 10 of Set 15 | cabras
# Processing Record 11 of Set 15 | grand-santi
# Processing Record 12 of Set 15 | yantal
# Processing Record 13 of Set 15 | yinchuan
# Processing Record 14 of Set 15 | west wendover
# Processing Record 15 of Set 15 | seidu
# Processing Record 16 of Set 15 | hailar
# Processing Record 17 of Set 15 | atikokan
# Processing Record 18 of Set 15 | beckley
# Processing Record 19 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 15 | kalat
# Processing Record 21 of Set 15 | puerto escondido
# Processing Record 22 of Set 15 | iba
# Processing Record 23 of Set 15 | mixquiahuala
# Processing Record 24 of Set 15 | lunca de sus
# Processing Record 25 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 15 | ereymentau
# Processing Record 28 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 15 | vangaindrano
# Processing Record 30 of Set 15 | galveston
# Processing Record 31 of Set 15 | lucea
# Processing Record 32 of Set 15 | zatoka
# Processing Record 33 of Set 15 | kargopol
# Processing Record 34 of Set 15 | sibolga
# Processing Record 35 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 36 of Set 15 | adre
# Processing Record 37 of Set 15 | sainte-rose
# Processing Record 38 of Set 15 | ca mau
# Processing Record 39 of Set 15 | senanga
# Processing Record 40 of Set 15 | saint-joseph
# Processing Record 41 of Set 15 | dunda
# Processing Record 42 of Set 15 | novoanninskiy
# Processing Record 43 of Set 15 | celestun
# Processing Record 44 of Set 15 | ye
# City not found. Skipping...
# Processing Record 45 of Set 15 | ouidah
# Processing Record 46 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 47 of Set 15 | kalmunai
# Processing Record 48 of Set 15 | tambul
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Clyde River      CA  70.4692  -68.5914     32.23        74          20
# 1         Rikitea      PF -23.1203 -134.9692     77.11        85          77
# 2  Cabo San Lucas      MX  22.8909 -109.9124     99.52        52         100
# 3        Hermanus      ZA -34.4187   19.2345     59.90        83          22
# 4            Lebu      CL -37.6167  -73.6500     53.80        66         100
# 5       Esperance      AU -33.8667  121.9000     60.64        84         100
# 6  Kulhudhuffushi      MV   6.6221   73.0700     83.55        70          47
# 7          Atuona      PF  -9.8000 -139.0333     78.69        72          11
# 8         Corinto      GR  37.9407   22.9573     75.02        70          30
# 9        Thompson      CA  55.7435  -97.8558     57.36        58          90
#
#    Wind Speed Current Description
# 0        3.44          few clouds
# 1       19.28       broken clouds
# 2        2.98     overcast clouds
# 3        2.46          light rain
# 4        5.93     overcast clouds
# 5       21.90     overcast clouds
# 6       21.92    scattered clouds
# 7       10.65          few clouds
# 8        7.16    scattered clouds
# 9       11.50     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/adamp/OneDrive/Desktop/Bootcamp/Module 6 - APIs/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
