# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pacifica
# Processing Record 2 of Set 1 | manta
# Processing Record 3 of Set 1 | acarau
# Processing Record 4 of Set 1 | roma
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | shieli
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | yar-sale
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | bati
# Processing Record 20 of Set 1 | olinda
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | sakaraha
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | morant bay
# Processing Record 26 of Set 1 | sisimiut
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | oistins
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 1 | lafiagi
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | college
# Processing Record 35 of Set 1 | thyboron
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | vestmanna
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | leningradskiy
# Processing Record 41 of Set 1 | kamareddi
# Processing Record 42 of Set 1 | gat
# Processing Record 43 of Set 1 | kyra
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | lembeni
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | beloha
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | innisfail
# Processing Record 50 of Set 1 | severodvinsk
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | mangai
# Processing Record 4 of Set 2 | uige
# Processing Record 5 of Set 2 | mahebourg
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | heihe
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | makinsk
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | fort nelson
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | padang
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | wasilla
# Processing Record 16 of Set 2 | praia
# Processing Record 17 of Set 2 | whangamata
# Processing Record 18 of Set 2 | lazaro cardenas
# Processing Record 19 of Set 2 | lianzhou
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | revadanda
# Processing Record 24 of Set 2 | rosarito
# Processing Record 25 of Set 2 | eureka
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | lahore
# Processing Record 29 of Set 2 | awka
# Processing Record 30 of Set 2 | hagenow
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 2 | kirya
# Processing Record 34 of Set 2 | san quintin
# Processing Record 35 of Set 2 | atar
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 2 | ponta do sol
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | bowen
# Processing Record 41 of Set 2 | genhe
# Processing Record 42 of Set 2 | paamiut
# Processing Record 43 of Set 2 | vao
# Processing Record 44 of Set 2 | sumbe
# Processing Record 45 of Set 2 | nizhniy tsasuchey
# Processing Record 46 of Set 2 | leopold
# Processing Record 47 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 2 | alyangula
# Processing Record 49 of Set 2 | duluth
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | talaya
# Processing Record 2 of Set 3 | capelinha
# Processing Record 3 of Set 3 | warrnambool
# Processing Record 4 of Set 3 | guerrero negro
# Processing Record 5 of Set 3 | pangoa
# Processing Record 6 of Set 3 | tamiahua
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | luanda
# Processing Record 9 of Set 3 | port antonio
# Processing Record 10 of Set 3 | hervey bay
# Processing Record 11 of Set 3 | lethem
# Processing Record 12 of Set 3 | vostok
# Processing Record 13 of Set 3 | severomuysk
# Processing Record 14 of Set 3 | pacific grove
# Processing Record 15 of Set 3 | camacari
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | chapais
# Processing Record 22 of Set 3 | maniitsoq
# Processing Record 23 of Set 3 | siavonga
# Processing Record 24 of Set 3 | aberdeen
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | grand-santi
# Processing Record 28 of Set 3 | matara
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | burnie
# Processing Record 33 of Set 3 | san juan de uraba
# Processing Record 34 of Set 3 | xining
# Processing Record 35 of Set 3 | kolpashevo
# Processing Record 36 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | pahrump
# Processing Record 39 of Set 3 | norman wells
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | czestochowa
# Processing Record 42 of Set 3 | umm kaddadah
# Processing Record 43 of Set 3 | manokwari
# Processing Record 44 of Set 3 | ulu-telyak
# Processing Record 45 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 3 | nybro
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | entre rios
# Processing Record 50 of Set 3 | comodoro rivadavia
# Processing Record 1 of Set 4 | bahia blanca
# Processing Record 2 of Set 4 | saint-pierre
# Processing Record 3 of Set 4 | rancho palos verdes
# Processing Record 4 of Set 4 | rio blanco
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | moron
# Processing Record 7 of Set 4 | havoysund
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | bull savanna
# Processing Record 10 of Set 4 | teya
# Processing Record 11 of Set 4 | brufut
# Processing Record 12 of Set 4 | sitka
# Processing Record 13 of Set 4 | ashqelon
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | lovozero
# Processing Record 18 of Set 4 | coahuayana
# Processing Record 19 of Set 4 | lagoa
# Processing Record 20 of Set 4 | ca mau
# Processing Record 21 of Set 4 | prabumulih
# Processing Record 22 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 4 | marsh harbour
# Processing Record 24 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 4 | pajan
# Processing Record 26 of Set 4 | byron bay
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | khandbari
# Processing Record 29 of Set 4 | jacmel
# Processing Record 30 of Set 4 | beyneu
# Processing Record 31 of Set 4 | amalapuram
# Processing Record 32 of Set 4 | san felipe
# Processing Record 33 of Set 4 | guangyuan
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | kavieng
# Processing Record 37 of Set 4 | kloulklubed
# Processing Record 38 of Set 4 | sao filipe
# Processing Record 39 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 4 | karlstad
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | tiznit
# Processing Record 43 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 4 | lorengau
# Processing Record 45 of Set 4 | arzgir
# Processing Record 46 of Set 4 | dunedin
# Processing Record 47 of Set 4 | shimoda
# Processing Record 48 of Set 4 | matagami
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | port hardy
# Processing Record 1 of Set 5 | usinsk
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | alta floresta
# Processing Record 4 of Set 5 | kapaa
# Processing Record 5 of Set 5 | san andres
# Processing Record 6 of Set 5 | takoradi
# Processing Record 7 of Set 5 | esna
# Processing Record 8 of Set 5 | port-cartier
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | xai-xai
# Processing Record 12 of Set 5 | faenza
# Processing Record 13 of Set 5 | vaini
# Processing Record 14 of Set 5 | namatanai
# Processing Record 15 of Set 5 | castro
# Processing Record 16 of Set 5 | fonte boa
# Processing Record 17 of Set 5 | sola
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | ampanihy
# Processing Record 20 of Set 5 | mityana
# Processing Record 21 of Set 5 | aksu
# Processing Record 22 of Set 5 | praia da vitoria
# Processing Record 23 of Set 5 | zeya
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | felanitx
# Processing Record 26 of Set 5 | mitu
# Processing Record 27 of Set 5 | te anau
# Processing Record 28 of Set 5 | fountain
# Processing Record 29 of Set 5 | kaeo
# Processing Record 30 of Set 5 | trincomalee
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | butaritari
# Processing Record 33 of Set 5 | esperance
# Processing Record 34 of Set 5 | stuttgart
# Processing Record 35 of Set 5 | sabang
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | san patricio
# Processing Record 38 of Set 5 | blyth
# Processing Record 39 of Set 5 | san jeronimo
# Processing Record 40 of Set 5 | winslow
# Processing Record 41 of Set 5 | vokhma
# Processing Record 42 of Set 5 | bethel
# Processing Record 43 of Set 5 | saint george
# Processing Record 44 of Set 5 | rocha
# Processing Record 45 of Set 5 | plettenberg bay
# Processing Record 46 of Set 5 | abnub
# Processing Record 47 of Set 5 | hailar
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 5 | kodiak
# Processing Record 1 of Set 6 | ginda
# Processing Record 2 of Set 6 | mandan
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | bahraich
# Processing Record 5 of Set 6 | dingle
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | burns lake
# Processing Record 8 of Set 6 | broome
# Processing Record 9 of Set 6 | sibolga
# Processing Record 10 of Set 6 | juli
# Processing Record 11 of Set 6 | kommunar
# Processing Record 12 of Set 6 | shreveport
# Processing Record 13 of Set 6 | codrington
# Processing Record 14 of Set 6 | meilu
# City not found. Skipping...
# Processing Record 15 of Set 6 | dobra
# Processing Record 16 of Set 6 | robertsport
# Processing Record 17 of Set 6 | suntar
# Processing Record 18 of Set 6 | maracaibo
# Processing Record 19 of Set 6 | salinopolis
# Processing Record 20 of Set 6 | ilulissat
# Processing Record 21 of Set 6 | vagur
# Processing Record 22 of Set 6 | khatanga
# Processing Record 23 of Set 6 | marrakesh
# Processing Record 24 of Set 6 | sobolevo
# Processing Record 25 of Set 6 | takaka
# Processing Record 26 of Set 6 | kenora
# Processing Record 27 of Set 6 | jumla
# Processing Record 28 of Set 6 | ust-nera
# Processing Record 29 of Set 6 | odweyne
# Processing Record 30 of Set 6 | boyolangu
# Processing Record 31 of Set 6 | port lincoln
# Processing Record 32 of Set 6 | flin flon
# Processing Record 33 of Set 6 | cabo san lucas
# Processing Record 34 of Set 6 | leshukonskoye
# Processing Record 35 of Set 6 | puerto del rosario
# Processing Record 36 of Set 6 | hambantota
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | cayenne
# Processing Record 39 of Set 6 | buraydah
# Processing Record 40 of Set 6 | tabou
# Processing Record 41 of Set 6 | arkhara
# Processing Record 42 of Set 6 | karlivka
# Processing Record 43 of Set 6 | araxa
# Processing Record 44 of Set 6 | panacan
# Processing Record 45 of Set 6 | souillac
# Processing Record 46 of Set 6 | luderitz
# Processing Record 47 of Set 6 | flinders
# Processing Record 48 of Set 6 | opuwo
# Processing Record 49 of Set 6 | new iberia
# Processing Record 50 of Set 6 | grindavik
# Processing Record 1 of Set 7 | paidha
# Processing Record 2 of Set 7 | cam ranh
# Processing Record 3 of Set 7 | nome
# Processing Record 4 of Set 7 | douglas
# Processing Record 5 of Set 7 | wajima
# Processing Record 6 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 7 of Set 7 | qaqortoq
# Processing Record 8 of Set 7 | miandrivazo
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | cap malheureux
# Processing Record 11 of Set 7 | umba
# Processing Record 12 of Set 7 | dengzhou
# Processing Record 13 of Set 7 | texarkana
# Processing Record 14 of Set 7 | prado
# Processing Record 15 of Set 7 | ostwald
# Processing Record 16 of Set 7 | acapulco
# Processing Record 17 of Set 7 | vanderhoof
# Processing Record 18 of Set 7 | strezhevoy
# Processing Record 19 of Set 7 | egvekinot
# Processing Record 20 of Set 7 | idil
# Processing Record 21 of Set 7 | dalvik
# Processing Record 22 of Set 7 | ramgarh
# Processing Record 23 of Set 7 | florianopolis
# Processing Record 24 of Set 7 | sioux lookout
# Processing Record 25 of Set 7 | abu kamal
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | excelsior springs
# Processing Record 28 of Set 7 | bambous virieux
# Processing Record 29 of Set 7 | westport
# Processing Record 30 of Set 7 | penzance
# Processing Record 31 of Set 7 | saint-michel-des-saints
# Processing Record 32 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 7 | shubarkuduk
# Processing Record 34 of Set 7 | poya
# Processing Record 35 of Set 7 | calabozo
# Processing Record 36 of Set 7 | port shepstone
# Processing Record 37 of Set 7 | hualmay
# Processing Record 38 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 39 of Set 7 | ust-tsilma
# Processing Record 40 of Set 7 | evensk
# Processing Record 41 of Set 7 | vanavara
# Processing Record 42 of Set 7 | mackay
# Processing Record 43 of Set 7 | ponta delgada
# Processing Record 44 of Set 7 | khandyga
# Processing Record 45 of Set 7 | great falls
# Processing Record 46 of Set 7 | bayan
# Processing Record 47 of Set 7 | tombouctou
# Processing Record 48 of Set 7 | bose
# Processing Record 49 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 7 | grand forks
# Processing Record 1 of Set 8 | richards bay
# Processing Record 2 of Set 8 | moree
# Processing Record 3 of Set 8 | kasongo-lunda
# Processing Record 4 of Set 8 | jilove u prahy
# Processing Record 5 of Set 8 | narsaq
# Processing Record 6 of Set 8 | tezu
# Processing Record 7 of Set 8 | burhaniye
# Processing Record 8 of Set 8 | zyryanka
# Processing Record 9 of Set 8 | lata
# Processing Record 10 of Set 8 | new ulm
# Processing Record 11 of Set 8 | vila franca do campo
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | launceston
# Processing Record 14 of Set 8 | serowe
# Processing Record 15 of Set 8 | caravelas
# Processing Record 16 of Set 8 | bac lieu
# Processing Record 17 of Set 8 | yerbogachen
# Processing Record 18 of Set 8 | moramanga
# Processing Record 19 of Set 8 | emirdag
# Processing Record 20 of Set 8 | yashan
# Processing Record 21 of Set 8 | rio grande
# Processing Record 22 of Set 8 | gari
# Processing Record 23 of Set 8 | sosnogorsk
# Processing Record 24 of Set 8 | cherskiy
# Processing Record 25 of Set 8 | itarema
# Processing Record 26 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 27 of Set 8 | sukaraja
# Processing Record 28 of Set 8 | nyuksenitsa
# Processing Record 29 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 8 | axim
# Processing Record 32 of Set 8 | guye
# Processing Record 33 of Set 8 | iberia
# Processing Record 34 of Set 8 | saint-augustin
# Processing Record 35 of Set 8 | arlit
# Processing Record 36 of Set 8 | seoul
# Processing Record 37 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 8 | asau
# Processing Record 39 of Set 8 | san pedro
# Processing Record 40 of Set 8 | kununurra
# Processing Record 41 of Set 8 | lasa
# Processing Record 42 of Set 8 | troitskoye
# Processing Record 43 of Set 8 | avera
# Processing Record 44 of Set 8 | chicama
# Processing Record 45 of Set 8 | maturin
# Processing Record 46 of Set 8 | bambari
# Processing Record 47 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 8 | mvuma
# Processing Record 49 of Set 8 | ahuimanu
# Processing Record 50 of Set 8 | husavik
# Processing Record 1 of Set 9 | okhotsk
# Processing Record 2 of Set 9 | laguna
# Processing Record 3 of Set 9 | haines junction
# Processing Record 4 of Set 9 | mombetsu
# Processing Record 5 of Set 9 | bubaque
# Processing Record 6 of Set 9 | kahului
# Processing Record 7 of Set 9 | polunochnoye
# Processing Record 8 of Set 9 | fort morgan
# Processing Record 9 of Set 9 | mbini
# Processing Record 10 of Set 9 | mudgee
# Processing Record 11 of Set 9 | lufilufi
# Processing Record 12 of Set 9 | kysyl-syr
# Processing Record 13 of Set 9 | lompoc
# Processing Record 14 of Set 9 | noumea
# Processing Record 15 of Set 9 | carutapera
# Processing Record 16 of Set 9 | huarmey
# Processing Record 17 of Set 9 | san cristobal
# Processing Record 18 of Set 9 | beringovskiy
# Processing Record 19 of Set 9 | awbari
# Processing Record 20 of Set 9 | nacala
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | akdepe
# Processing Record 23 of Set 9 | lidkoping
# Processing Record 24 of Set 9 | maragogi
# Processing Record 25 of Set 9 | pandamatenga
# Processing Record 26 of Set 9 | kungurtug
# Processing Record 27 of Set 9 | gazli
# Processing Record 28 of Set 9 | margate
# Processing Record 29 of Set 9 | saldanha
# Processing Record 30 of Set 9 | kjollefjord
# Processing Record 31 of Set 9 | burica
# City not found. Skipping...
# Processing Record 32 of Set 9 | payson
# Processing Record 33 of Set 9 | zhanaozen
# Processing Record 34 of Set 9 | tual
# Processing Record 35 of Set 9 | tambacounda
# Processing Record 36 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 37 of Set 9 | toamasina
# Processing Record 38 of Set 9 | ouargaye
# Processing Record 39 of Set 9 | inhambane
# Processing Record 40 of Set 9 | loukhi
# Processing Record 41 of Set 9 | grivenskaya
# Processing Record 42 of Set 9 | port keats
# Processing Record 43 of Set 9 | almeirim
# Processing Record 44 of Set 9 | ukiah
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | itoman
# Processing Record 47 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 9 | ixtapa
# Processing Record 49 of Set 9 | pemangkat
# Processing Record 50 of Set 9 | zhangjiakou
# Processing Record 1 of Set 10 | fairbanks
# Processing Record 2 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 10 | teknaf
# Processing Record 4 of Set 10 | kushiro
# Processing Record 5 of Set 10 | bagakay
# Processing Record 6 of Set 10 | santa maria de jesus
# Processing Record 7 of Set 10 | arman
# Processing Record 8 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 10 | port blair
# Processing Record 10 of Set 10 | nyakahanga
# Processing Record 11 of Set 10 | arica
# Processing Record 12 of Set 10 | shache
# Processing Record 13 of Set 10 | alugan
# Processing Record 14 of Set 10 | miri
# Processing Record 15 of Set 10 | nabire
# Processing Record 16 of Set 10 | santa ines
# Processing Record 17 of Set 10 | luoyang
# Processing Record 18 of Set 10 | clemson
# Processing Record 19 of Set 10 | beira
# Processing Record 20 of Set 10 | arkhangelsk
# Processing Record 21 of Set 10 | zhob
# Processing Record 22 of Set 10 | bheramara
# Processing Record 23 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 10 | roccastrada
# Processing Record 25 of Set 10 | kondinskoye
# Processing Record 26 of Set 10 | muros
# Processing Record 27 of Set 10 | katsuura
# Processing Record 28 of Set 10 | ossora
# Processing Record 29 of Set 10 | guiyang
# Processing Record 30 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 10 | rincon
# Processing Record 32 of Set 10 | turukhansk
# Processing Record 33 of Set 10 | labrea
# Processing Record 34 of Set 10 | santa maria
# Processing Record 35 of Set 10 | chara
# Processing Record 36 of Set 10 | niltepec
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | sao francisco de assis
# Processing Record 39 of Set 10 | yialos
# City not found. Skipping...
# Processing Record 40 of Set 10 | ancud
# Processing Record 41 of Set 10 | nanortalik
# Processing Record 42 of Set 10 | pangody
# Processing Record 43 of Set 10 | geraldton
# Processing Record 44 of Set 10 | zhirnovsk
# Processing Record 45 of Set 10 | muroto
# Processing Record 46 of Set 10 | papara
# Processing Record 47 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 48 of Set 10 | george
# Processing Record 49 of Set 10 | kruisfontein
# Processing Record 50 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 11 | iwanai
# Processing Record 2 of Set 11 | port-gentil
# Processing Record 3 of Set 11 | namibe
# Processing Record 4 of Set 11 | champerico
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | nouna
# Processing Record 7 of Set 11 | riberalta
# Processing Record 8 of Set 11 | adrar
# Processing Record 9 of Set 11 | kwinana
# Processing Record 10 of Set 11 | touros
# Processing Record 11 of Set 11 | metro
# Processing Record 12 of Set 11 | boden
# Processing Record 13 of Set 11 | bukama
# Processing Record 14 of Set 11 | henties bay
# Processing Record 15 of Set 11 | jaca
# Processing Record 16 of Set 11 | baykit
# Processing Record 17 of Set 11 | carmo do rio verde
# Processing Record 18 of Set 11 | merauke
# Processing Record 19 of Set 11 | brae
# Processing Record 20 of Set 11 | makasar
# Processing Record 21 of Set 11 | boromo
# Processing Record 22 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 11 | yatou
# Processing Record 24 of Set 11 | miquelon
# Processing Record 25 of Set 11 | hovd
# Processing Record 26 of Set 11 | camacha
# Processing Record 27 of Set 11 | karasjok
# Processing Record 28 of Set 11 | komsomolskiy
# Processing Record 29 of Set 11 | novikovo
# Processing Record 30 of Set 11 | abu dhabi
# Processing Record 31 of Set 11 | gezing
# Processing Record 32 of Set 11 | sakakah
# Processing Record 33 of Set 11 | borovichi
# Processing Record 34 of Set 11 | torbay
# Processing Record 35 of Set 11 | nyurba
# Processing Record 36 of Set 11 | ostersund
# Processing Record 37 of Set 11 | ostrovnoy
# Processing Record 38 of Set 11 | stykkisholmur
# Processing Record 39 of Set 11 | cockburn town
# Processing Record 40 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 41 of Set 11 | santiago del estero
# Processing Record 42 of Set 11 | roald
# Processing Record 43 of Set 11 | seybaplaya
# Processing Record 44 of Set 11 | peddapuram
# Processing Record 45 of Set 11 | venado tuerto
# Processing Record 46 of Set 11 | zhezkazgan
# Processing Record 47 of Set 11 | libreville
# Processing Record 48 of Set 11 | tura
# Processing Record 49 of Set 11 | gorkovskoye
# City not found. Skipping...
# Processing Record 50 of Set 11 | isiro
# Processing Record 1 of Set 12 | baruun-urt
# Processing Record 2 of Set 12 | marquette
# Processing Record 3 of Set 12 | mareeba
# Processing Record 4 of Set 12 | seminole
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | mugumu
# Processing Record 7 of Set 12 | tuban
# Processing Record 8 of Set 12 | benghazi
# Processing Record 9 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 12 | cardston
# Processing Record 11 of Set 12 | mount isa
# Processing Record 12 of Set 12 | kokemaki
# Processing Record 13 of Set 12 | suez
# Processing Record 14 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 12 | uglegorsk
# Processing Record 16 of Set 12 | lugo
# Processing Record 17 of Set 12 | strelca
# City not found. Skipping...
# Processing Record 18 of Set 12 | mayo
# Processing Record 19 of Set 12 | mecca
# Processing Record 20 of Set 12 | gao
# Processing Record 21 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 12 | milkovo
# Processing Record 23 of Set 12 | rudnya
# Processing Record 24 of Set 12 | bay roberts
# Processing Record 25 of Set 12 | calvillo
# Processing Record 26 of Set 12 | manuk mangkaw
# Processing Record 27 of Set 12 | porto seguro
# Processing Record 28 of Set 12 | igarka
# Processing Record 29 of Set 12 | camocim
# Processing Record 30 of Set 12 | payakumbuh
# Processing Record 31 of Set 12 | half moon bay
# Processing Record 32 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 33 of Set 12 | lamu
# Processing Record 34 of Set 12 | sherghati
# Processing Record 35 of Set 12 | kangaatsiaq
# Processing Record 36 of Set 12 | chanute
# Processing Record 37 of Set 12 | thinadhoo
# Processing Record 38 of Set 12 | aklavik
# Processing Record 39 of Set 12 | nuevo progreso
# Processing Record 40 of Set 12 | skiathos
# Processing Record 41 of Set 12 | kirakira
# Processing Record 42 of Set 12 | bolshoy uluy
# City not found. Skipping...
# Processing Record 43 of Set 12 | mwinilunga
# Processing Record 44 of Set 12 | tateyama
# Processing Record 45 of Set 12 | sechura
# Processing Record 46 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 48 of Set 12 | ugoofaaru
# Processing Record 49 of Set 12 | mount pleasant
# Processing Record 50 of Set 12 | changtu
# Processing Record 1 of Set 13 | vaitape
# Processing Record 2 of Set 13 | nishihara
# Processing Record 3 of Set 13 | fomboni
# Processing Record 4 of Set 13 | aranos
# Processing Record 5 of Set 13 | shelburne
# Processing Record 6 of Set 13 | elko
# Processing Record 7 of Set 13 | broken hill
# Processing Record 8 of Set 13 | goderich
# Processing Record 9 of Set 13 | san javier
# Processing Record 10 of Set 13 | port augusta
# Processing Record 11 of Set 13 | yarensk
# Processing Record 12 of Set 13 | mersing
# Processing Record 13 of Set 13 | tukrah
# Processing Record 14 of Set 13 | maryville
# Processing Record 15 of Set 13 | mamlyutka
# Processing Record 16 of Set 13 | manohar thana
# Processing Record 17 of Set 13 | marzuq
# Processing Record 18 of Set 13 | mazatlan
# Processing Record 19 of Set 13 | owando
# Processing Record 20 of Set 13 | la motte-servolex
# Processing Record 21 of Set 13 | liwale
# Processing Record 22 of Set 13 | naze
# Processing Record 23 of Set 13 | doha
# Processing Record 24 of Set 13 | vila velha
# Processing Record 25 of Set 13 | mount gambier
# Processing Record 26 of Set 13 | mandalgovi
# Processing Record 27 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 13 | carroll
# Processing Record 29 of Set 13 | musoma
# Processing Record 30 of Set 13 | pochutla
# Processing Record 31 of Set 13 | awjilah
# Processing Record 32 of Set 13 | araouane
# Processing Record 33 of Set 13 | alamosa
# Processing Record 34 of Set 13 | kansanshi
# Processing Record 35 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 13 | balkhash
# Processing Record 37 of Set 13 | atbasar
# Processing Record 38 of Set 13 | diamantino
# Processing Record 39 of Set 13 | skjervoy
# Processing Record 40 of Set 13 | houston
# Processing Record 41 of Set 13 | altonia
# City not found. Skipping...
# Processing Record 42 of Set 13 | hendijan
# City not found. Skipping...
# Processing Record 43 of Set 13 | didwana
# Processing Record 44 of Set 13 | kudahuvadhoo
# Processing Record 45 of Set 13 | virton
# Processing Record 46 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 13 | austin
# Processing Record 48 of Set 13 | mawlaik
# Processing Record 49 of Set 13 | deputatskiy
# Processing Record 50 of Set 13 | popondetta
# Processing Record 1 of Set 14 | kroonstad
# Processing Record 2 of Set 14 | newton
# Processing Record 3 of Set 14 | hirara
# Processing Record 4 of Set 14 | erenhot
# Processing Record 5 of Set 14 | jalu
# Processing Record 6 of Set 14 | smithers
# Processing Record 7 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 14 | homer
# Processing Record 9 of Set 14 | nagato
# Processing Record 10 of Set 14 | korem
# Processing Record 11 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 12 of Set 14 | mehamn
# Processing Record 13 of Set 14 | sebinkarahisar
# Processing Record 14 of Set 14 | sueyoshi
# Processing Record 15 of Set 14 | obodivka
# Processing Record 16 of Set 14 | umea
# Processing Record 17 of Set 14 | krasnoselkup
# Processing Record 18 of Set 14 | srednekolymsk
# Processing Record 19 of Set 14 | puteyets
# Processing Record 20 of Set 14 | phanom sarakham
# Processing Record 21 of Set 14 | port moresby
# Processing Record 22 of Set 14 | novodugino
# Processing Record 23 of Set 14 | trairi
# Processing Record 24 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 14 | port hedland
# Processing Record 26 of Set 14 | yanam
# Processing Record 27 of Set 14 | el astillero
# Processing Record 28 of Set 14 | faanui
# Processing Record 29 of Set 14 | pangkalanbuun
# Processing Record 30 of Set 14 | allada
# Processing Record 31 of Set 14 | nantucket
# Processing Record 32 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 33 of Set 14 | ucluelet
# Processing Record 34 of Set 14 | malibu
# Processing Record 35 of Set 14 | meulaboh
# Processing Record 36 of Set 14 | ornskoldsvik
# Processing Record 37 of Set 14 | hof
# Processing Record 38 of Set 14 | slave lake
# Processing Record 39 of Set 14 | bani walid
# Processing Record 40 of Set 14 | san carlos de bariloche
# Processing Record 41 of Set 14 | xghajra
# City not found. Skipping...
# Processing Record 42 of Set 14 | murmashi
# Processing Record 43 of Set 14 | newport
# Processing Record 44 of Set 14 | gzhatsk
# City not found. Skipping...
# Processing Record 45 of Set 14 | natchez
# Processing Record 46 of Set 14 | pangnirtung
# Processing Record 47 of Set 14 | sayville
# Processing Record 48 of Set 14 | alice springs
# Processing Record 49 of Set 14 | bilma
# Processing Record 50 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 15 | behshahr
# Processing Record 3 of Set 15 | anadyr
# Processing Record 4 of Set 15 | waingapu
# Processing Record 5 of Set 15 | mayor pablo lagerenza
# Processing Record 6 of Set 15 | necochea
# Processing Record 7 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 15 | monte patria
# Processing Record 9 of Set 15 | waipawa
# Processing Record 10 of Set 15 | kovdor
# Processing Record 11 of Set 15 | iturama
# Processing Record 12 of Set 15 | antofagasta
# Processing Record 13 of Set 15 | pelym
# Processing Record 14 of Set 15 | linjiang
# Processing Record 15 of Set 15 | angoche
# Processing Record 16 of Set 15 | baillif
# Processing Record 17 of Set 15 | kiruna
# Processing Record 18 of Set 15 | nizhnyaya omka
# Processing Record 19 of Set 15 | we
# City not found. Skipping...
# Processing Record 20 of Set 15 | marawi
# Processing Record 21 of Set 15 | azua
# Processing Record 22 of Set 15 | nhulunbuy
# Processing Record 23 of Set 15 | portland
# Processing Record 24 of Set 15 | san luis
# Processing Record 25 of Set 15 | gorontalo
# Processing Record 26 of Set 15 | riverton
# Processing Record 27 of Set 15 | eyl
# Processing Record 28 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 15 | wokha
# Processing Record 30 of Set 15 | kargil
# Processing Record 31 of Set 15 | lukh
# Processing Record 32 of Set 15 | boli
# Processing Record 33 of Set 15 | soyo
# Processing Record 34 of Set 15 | serenje
# Processing Record 35 of Set 15 | mackenzie
# Processing Record 36 of Set 15 | chake chake
# Processing Record 37 of Set 15 | tynda
# Processing Record 38 of Set 15 | kamina
# Processing Record 39 of Set 15 | arak
# Processing Record 40 of Set 15 | kargasok
# Processing Record 41 of Set 15 | kamaishi
# Processing Record 42 of Set 15 | ouesso
# Processing Record 43 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 15 | mocuba
# Processing Record 45 of Set 15 | saint anthony
# Processing Record 46 of Set 15 | khasan
# Processing Record 47 of Set 15 | oum hadjer
# Processing Record 48 of Set 15 | bagnes
# Processing Record 49 of Set 15 | paita
# Processing Record 50 of Set 15 | bignona
# Processing Record 1 of Set 16 | tsienyane
# City not found. Skipping...
# Processing Record 2 of Set 16 | muli
# Processing Record 3 of Set 16 | backa palanka
# Processing Record 4 of Set 16 | gandajika
# Processing Record 5 of Set 16 | pitimbu
# Processing Record 6 of Set 16 | sibu
# Processing Record 7 of Set 16 | dolores
# Processing Record 8 of Set 16 | carnduff
# Processing Record 9 of Set 16 | mahon
# Processing Record 10 of Set 16 | emba
# Processing Record 11 of Set 16 | brigantine
# Processing Record 12 of Set 16 | angra
# City not found. Skipping...
# Processing Record 13 of Set 16 | talcahuano
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Pacifica      US  37.6138 -122.4869     65.34        88          75
# 1         Manta      EC  -0.9500  -80.7333     79.14        75          91
# 2        Acarau      BR  -2.8856  -40.1200     86.14        63          68
# 3          Roma      US  43.2128  -75.4557     58.86        69         100
# 4        Hobart      AU -42.8794  147.3294     46.26        76          90
# 5       Qaanaaq      GL  77.4840  -69.3632     32.27        94          36
# 6         Bluff      NZ -46.6000  168.3333     49.80        87         100
# 7        Shieli      KZ  44.1667   66.7500     79.99        39          81
# 8       Ushuaia      AR -54.8000  -68.3000     29.30        88          94
# 9  Puerto Ayora      EC  -0.7393  -90.3518     77.56        84          55
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1        7.34     overcast clouds
# 2       12.53       broken clouds
# 3        7.00     overcast clouds
# 4        1.99     overcast clouds
# 5        5.84    scattered clouds
# 6       19.75     overcast clouds
# 7        5.17       broken clouds
# 8       10.18          light snow
# 9        8.01       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/adamp/OneDrive/Desktop/Bootcamp/Module 6 - APIs/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
