# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 795

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bontang
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | ubinskoye
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | akil
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | ayagoz
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | harper
# Processing Record 14 of Set 1 | marsh harbour
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | pangnirtung
# Processing Record 17 of Set 1 | ponta do sol
# Processing Record 18 of Set 1 | salekhard
# Processing Record 19 of Set 1 | laguna
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | fortuna
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | dambulla
# Processing Record 27 of Set 1 | ormond beach
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | bathsheba
# Processing Record 30 of Set 1 | prado
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | ostrovnoy
# Processing Record 33 of Set 1 | sakaraha
# Processing Record 34 of Set 1 | palo pintado
# City not found. Skipping...
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | moba
# Processing Record 37 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | mindelo
# Processing Record 46 of Set 1 | george
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | maarianhamina
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 3 of Set 2 | chancay
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | kalemie
# Processing Record 8 of Set 2 | miri
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | lorengau
# Processing Record 11 of Set 2 | tara
# Processing Record 12 of Set 2 | airai
# Processing Record 13 of Set 2 | mogochin
# City not found. Skipping...
# Processing Record 14 of Set 2 | castrillon
# Processing Record 15 of Set 2 | ahipara
# Processing Record 16 of Set 2 | general pico
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | suzun
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | yenagoa
# Processing Record 22 of Set 2 | cartagena
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | isangel
# Processing Record 25 of Set 2 | mweka
# Processing Record 26 of Set 2 | santa clara
# Processing Record 27 of Set 2 | butaritari
# Processing Record 28 of Set 2 | kawalu
# Processing Record 29 of Set 2 | kurduvadi
# Processing Record 30 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 2 | heihe
# Processing Record 32 of Set 2 | awbari
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | port hedland
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | ambon
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | uaua
# Processing Record 39 of Set 2 | guajara-mirim
# City not found. Skipping...
# Processing Record 40 of Set 2 | araouane
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | andra
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 2 | hofn
# Processing Record 46 of Set 2 | leningradskiy
# Processing Record 47 of Set 2 | buin
# Processing Record 48 of Set 2 | busselton
# Processing Record 49 of Set 2 | klaksvik
# Processing Record 50 of Set 2 | seminole
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 3 | vestmannaeyjar
# Processing Record 4 of Set 3 | sinnamary
# Processing Record 5 of Set 3 | kieta
# Processing Record 6 of Set 3 | port hardy
# Processing Record 7 of Set 3 | henties bay
# Processing Record 8 of Set 3 | hithadhoo
# Processing Record 9 of Set 3 | kibray
# Processing Record 10 of Set 3 | arenillas
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | takoradi
# Processing Record 13 of Set 3 | bandarbeyla
# Processing Record 14 of Set 3 | bredasdorp
# Processing Record 15 of Set 3 | hays
# Processing Record 16 of Set 3 | mormugao
# Processing Record 17 of Set 3 | beisfjord
# Processing Record 18 of Set 3 | abha
# Processing Record 19 of Set 3 | teahupoo
# Processing Record 20 of Set 3 | norman wells
# Processing Record 21 of Set 3 | teacapan
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | lata
# Processing Record 24 of Set 3 | kingsport
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 3 | bridlington
# Processing Record 28 of Set 3 | daru
# Processing Record 29 of Set 3 | kruisfontein
# Processing Record 30 of Set 3 | kimbe
# Processing Record 31 of Set 3 | oktyabrskoye
# Processing Record 32 of Set 3 | quelimane
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | lahad datu
# Processing Record 36 of Set 3 | sept-iles
# Processing Record 37 of Set 3 | kushiro
# Processing Record 38 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 3 | bobonong
# City not found. Skipping...
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | muhos
# Processing Record 42 of Set 3 | assiniboia
# Processing Record 43 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 3 | rivera
# Processing Record 45 of Set 3 | moroto
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | katsuura
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | luderitz
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | yarada
# Processing Record 2 of Set 4 | atuona
# Processing Record 3 of Set 4 | umm kaddadah
# Processing Record 4 of Set 4 | zacualpan
# Processing Record 5 of Set 4 | astoria
# Processing Record 6 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 4 | ampanihy
# Processing Record 8 of Set 4 | kapaa
# Processing Record 9 of Set 4 | del rio
# Processing Record 10 of Set 4 | pisco
# Processing Record 11 of Set 4 | wladyslawowo
# Processing Record 12 of Set 4 | victoria
# Processing Record 13 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | anahuac
# Processing Record 18 of Set 4 | pacific grove
# Processing Record 19 of Set 4 | saint-medard-en-jalles
# Processing Record 20 of Set 4 | gunjur
# Processing Record 21 of Set 4 | cabadiangan
# Processing Record 22 of Set 4 | kendari
# Processing Record 23 of Set 4 | rocha
# Processing Record 24 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | port lincoln
# Processing Record 27 of Set 4 | east london
# Processing Record 28 of Set 4 | arraial do cabo
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | kichera
# Processing Record 31 of Set 4 | hamilton
# Processing Record 32 of Set 4 | boa vista
# Processing Record 33 of Set 4 | sao filipe
# Processing Record 34 of Set 4 | lysva
# Processing Record 35 of Set 4 | sri aman
# Processing Record 36 of Set 4 | carnarvon
# Processing Record 37 of Set 4 | micheweni
# Processing Record 38 of Set 4 | sitka
# Processing Record 39 of Set 4 | sibolga
# Processing Record 40 of Set 4 | yar-sale
# Processing Record 41 of Set 4 | comodoro rivadavia
# Processing Record 42 of Set 4 | porto murtinho
# Processing Record 43 of Set 4 | arlit
# Processing Record 44 of Set 4 | aksarka
# Processing Record 45 of Set 4 | evensk
# Processing Record 46 of Set 4 | palmer
# Processing Record 47 of Set 4 | vidim
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | metro
# Processing Record 50 of Set 4 | funtua
# Processing Record 1 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 5 | betanzos
# Processing Record 3 of Set 5 | thompson
# Processing Record 4 of Set 5 | fountain
# Processing Record 5 of Set 5 | fort saint james
# Processing Record 6 of Set 5 | chuy
# Processing Record 7 of Set 5 | oktyabrskiy
# Processing Record 8 of Set 5 | casa nova
# Processing Record 9 of Set 5 | mar del plata
# Processing Record 10 of Set 5 | kanniyakumari
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | myitkyina
# Processing Record 13 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 5 | rani
# Processing Record 15 of Set 5 | kloulklubed
# Processing Record 16 of Set 5 | beirut
# Processing Record 17 of Set 5 | bingol
# Processing Record 18 of Set 5 | rio gallegos
# Processing Record 19 of Set 5 | chilac
# City not found. Skipping...
# Processing Record 20 of Set 5 | kavaratti
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | almunecar
# Processing Record 23 of Set 5 | mahebourg
# Processing Record 24 of Set 5 | atka
# City not found. Skipping...
# Processing Record 25 of Set 5 | callejones
# Processing Record 26 of Set 5 | turbat
# Processing Record 27 of Set 5 | catamarca
# Processing Record 28 of Set 5 | sidi bin nur
# Processing Record 29 of Set 5 | puerto asis
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | powell river
# Processing Record 33 of Set 5 | ixtapa
# Processing Record 34 of Set 5 | uppsala
# Processing Record 35 of Set 5 | bengkulu
# Processing Record 36 of Set 5 | inhambane
# Processing Record 37 of Set 5 | le port
# Processing Record 38 of Set 5 | phan thiet
# Processing Record 39 of Set 5 | mindif
# Processing Record 40 of Set 5 | sogdiondon
# City not found. Skipping...
# Processing Record 41 of Set 5 | kodiak
# Processing Record 42 of Set 5 | botngard
# Processing Record 43 of Set 5 | lagoa
# Processing Record 44 of Set 5 | jaisalmer
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | namibe
# Processing Record 47 of Set 5 | cayenne
# Processing Record 48 of Set 5 | qena
# Processing Record 49 of Set 5 | dutlwe
# Processing Record 50 of Set 5 | barahona
# Processing Record 1 of Set 6 | komsomolskiy
# Processing Record 2 of Set 6 | ilheus
# Processing Record 3 of Set 6 | gat
# Processing Record 4 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 5 of Set 6 | osoyoos
# Processing Record 6 of Set 6 | hare bay
# Processing Record 7 of Set 6 | pamanukan
# Processing Record 8 of Set 6 | bardiyah
# Processing Record 9 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 6 | meulaboh
# Processing Record 11 of Set 6 | bollnas
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | shima
# Processing Record 15 of Set 6 | dali
# Processing Record 16 of Set 6 | jardim
# Processing Record 17 of Set 6 | whitianga
# Processing Record 18 of Set 6 | monterey
# Processing Record 19 of Set 6 | adrar
# Processing Record 20 of Set 6 | sarangani
# Processing Record 21 of Set 6 | areia branca
# Processing Record 22 of Set 6 | balangir
# Processing Record 23 of Set 6 | gorontalo
# Processing Record 24 of Set 6 | kaitangata
# Processing Record 25 of Set 6 | darnah
# Processing Record 26 of Set 6 | booue
# Processing Record 27 of Set 6 | lamar
# Processing Record 28 of Set 6 | havre de grace
# Processing Record 29 of Set 6 | coahuayana
# Processing Record 30 of Set 6 | san joaquin
# Processing Record 31 of Set 6 | hearst
# Processing Record 32 of Set 6 | komsomolets
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | tuktoyaktuk
# Processing Record 35 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 36 of Set 6 | cerrito
# Processing Record 37 of Set 6 | oum hadjer
# Processing Record 38 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 6 | chizhou
# Processing Record 40 of Set 6 | piacabucu
# Processing Record 41 of Set 6 | fairbanks
# Processing Record 42 of Set 6 | khandyga
# Processing Record 43 of Set 6 | shelburne
# Processing Record 44 of Set 6 | qaanaaq
# Processing Record 45 of Set 6 | saskylakh
# Processing Record 46 of Set 6 | mukhtolovo
# Processing Record 47 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 6 | acari
# Processing Record 50 of Set 6 | ola
# Processing Record 1 of Set 7 | abu samrah
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | kodinsk
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | koungou
# Processing Record 6 of Set 7 | alta floresta
# Processing Record 7 of Set 7 | armeria
# Processing Record 8 of Set 7 | richards bay
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | okitipupa
# Processing Record 11 of Set 7 | lugui
# Processing Record 12 of Set 7 | vitre
# Processing Record 13 of Set 7 | naze
# Processing Record 14 of Set 7 | high prairie
# Processing Record 15 of Set 7 | elban
# Processing Record 16 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 7 | buala
# Processing Record 18 of Set 7 | talbahat
# Processing Record 19 of Set 7 | novodolinskiy
# Processing Record 20 of Set 7 | khudumelapye
# Processing Record 21 of Set 7 | omboue
# Processing Record 22 of Set 7 | waw
# Processing Record 23 of Set 7 | talcahuano
# Processing Record 24 of Set 7 | russell
# Processing Record 25 of Set 7 | egvekinot
# Processing Record 26 of Set 7 | izumo
# Processing Record 27 of Set 7 | aklavik
# Processing Record 28 of Set 7 | sola
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | pangoa
# Processing Record 31 of Set 7 | rudbar
# Processing Record 32 of Set 7 | saint george
# Processing Record 33 of Set 7 | siyabuswa
# Processing Record 34 of Set 7 | nyurba
# Processing Record 35 of Set 7 | deputatskiy
# Processing Record 36 of Set 7 | sarevere
# Processing Record 37 of Set 7 | kwekwe
# Processing Record 38 of Set 7 | cascais
# Processing Record 39 of Set 7 | robe
# Processing Record 40 of Set 7 | namatanai
# Processing Record 41 of Set 7 | poum
# Processing Record 42 of Set 7 | sao jose da coroa grande
# Processing Record 43 of Set 7 | sungaipenuh
# Processing Record 44 of Set 7 | mildura
# Processing Record 45 of Set 7 | metehara
# City not found. Skipping...
# Processing Record 46 of Set 7 | vrangel
# Processing Record 47 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 7 | olinda
# Processing Record 49 of Set 7 | taoudenni
# Processing Record 50 of Set 7 | derzhavinsk
# Processing Record 1 of Set 8 | rochegda
# Processing Record 2 of Set 8 | olafsvik
# Processing Record 3 of Set 8 | tazovskiy
# Processing Record 4 of Set 8 | san jose
# Processing Record 5 of Set 8 | faanui
# Processing Record 6 of Set 8 | kovernino
# Processing Record 7 of Set 8 | guerrero negro
# Processing Record 8 of Set 8 | ulaanbaatar
# Processing Record 9 of Set 8 | ornskoldsvik
# Processing Record 10 of Set 8 | sandnessjoen
# Processing Record 11 of Set 8 | north platte
# Processing Record 12 of Set 8 | izhmorskiy
# Processing Record 13 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 8 | umba
# Processing Record 15 of Set 8 | kahului
# Processing Record 16 of Set 8 | mandurah
# Processing Record 17 of Set 8 | turayf
# Processing Record 18 of Set 8 | upernavik
# Processing Record 19 of Set 8 | karratha
# Processing Record 20 of Set 8 | viedma
# Processing Record 21 of Set 8 | nago
# Processing Record 22 of Set 8 | chengdu
# Processing Record 23 of Set 8 | harindanga
# Processing Record 24 of Set 8 | dikson
# Processing Record 25 of Set 8 | terme
# Processing Record 26 of Set 8 | manado
# Processing Record 27 of Set 8 | platanos
# Processing Record 28 of Set 8 | northam
# Processing Record 29 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 8 | lompoc
# Processing Record 31 of Set 8 | bocaranga
# City not found. Skipping...
# Processing Record 32 of Set 8 | qaqortoq
# Processing Record 33 of Set 8 | grenaa
# Processing Record 34 of Set 8 | rorvik
# Processing Record 35 of Set 8 | lucapa
# Processing Record 36 of Set 8 | iberia
# Processing Record 37 of Set 8 | axim
# Processing Record 38 of Set 8 | erzin
# Processing Record 39 of Set 8 | bambous virieux
# Processing Record 40 of Set 8 | husavik
# Processing Record 41 of Set 8 | biak
# Processing Record 42 of Set 8 | padang
# Processing Record 43 of Set 8 | devils lake
# Processing Record 44 of Set 8 | futtsu
# Processing Record 45 of Set 8 | salalah
# Processing Record 46 of Set 8 | carmelo
# Processing Record 47 of Set 8 | ust-nera
# Processing Record 48 of Set 8 | jinchang
# Processing Record 49 of Set 8 | sur
# Processing Record 50 of Set 8 | sao felix do xingu
# Processing Record 1 of Set 9 | san agustin
# Processing Record 2 of Set 9 | sosnovoborsk
# Processing Record 3 of Set 9 | belokurikha
# Processing Record 4 of Set 9 | cap malheureux
# Processing Record 5 of Set 9 | nouadhibou
# Processing Record 6 of Set 9 | zambezi
# Processing Record 7 of Set 9 | play cu
# City not found. Skipping...
# Processing Record 8 of Set 9 | touros
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | sanmenxia
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | berlevag
# Processing Record 13 of Set 9 | emerald
# Processing Record 14 of Set 9 | biltine
# Processing Record 15 of Set 9 | vila
# Processing Record 16 of Set 9 | qasigiannguit
# Processing Record 17 of Set 9 | corrente
# Processing Record 18 of Set 9 | felanitx
# Processing Record 19 of Set 9 | grand baie
# Processing Record 20 of Set 9 | hami
# Processing Record 21 of Set 9 | tingi
# Processing Record 22 of Set 9 | lavrentiya
# Processing Record 23 of Set 9 | ballina
# Processing Record 24 of Set 9 | buchanan
# Processing Record 25 of Set 9 | maceio
# Processing Record 26 of Set 9 | tabora
# Processing Record 27 of Set 9 | samarai
# Processing Record 28 of Set 9 | zyryanka
# Processing Record 29 of Set 9 | cabo san lucas
# Processing Record 30 of Set 9 | linqiong
# Processing Record 31 of Set 9 | odder
# Processing Record 32 of Set 9 | yamada
# Processing Record 33 of Set 9 | aswan
# Processing Record 34 of Set 9 | nhulunbuy
# Processing Record 35 of Set 9 | san andres
# Processing Record 36 of Set 9 | san miguel
# Processing Record 37 of Set 9 | manadhoo
# Processing Record 38 of Set 9 | mopipi
# Processing Record 39 of Set 9 | chilliwack
# Processing Record 40 of Set 9 | sabang
# Processing Record 41 of Set 9 | governador dix-sept rosado
# Processing Record 42 of Set 9 | morros
# Processing Record 43 of Set 9 | havoysund
# Processing Record 44 of Set 9 | fergus falls
# Processing Record 45 of Set 9 | bombay
# Processing Record 46 of Set 9 | koumac
# Processing Record 47 of Set 9 | victor harbor
# Processing Record 48 of Set 9 | whitehorse
# Processing Record 49 of Set 9 | vardo
# Processing Record 50 of Set 9 | muros
# Processing Record 1 of Set 10 | narsaq
# Processing Record 2 of Set 10 | caravelas
# Processing Record 3 of Set 10 | baijiantan
# Processing Record 4 of Set 10 | sayyan
# Processing Record 5 of Set 10 | havelock
# Processing Record 6 of Set 10 | roebourne
# Processing Record 7 of Set 10 | praia da vitoria
# Processing Record 8 of Set 10 | atar
# Processing Record 9 of Set 10 | kangaba
# Processing Record 10 of Set 10 | itoman
# Processing Record 11 of Set 10 | ulaangom
# Processing Record 12 of Set 10 | ilo
# Processing Record 13 of Set 10 | pathein
# Processing Record 14 of Set 10 | mount isa
# Processing Record 15 of Set 10 | totness
# Processing Record 16 of Set 10 | elko
# Processing Record 17 of Set 10 | athabasca
# Processing Record 18 of Set 10 | kailua
# Processing Record 19 of Set 10 | kuala terengganu
# Processing Record 20 of Set 10 | chany
# Processing Record 21 of Set 10 | helong
# Processing Record 22 of Set 10 | lima
# Processing Record 23 of Set 10 | chingirlau
# Processing Record 24 of Set 10 | srednekolymsk
# Processing Record 25 of Set 10 | blonduos
# City not found. Skipping...
# Processing Record 26 of Set 10 | saint anthony
# Processing Record 27 of Set 10 | severobaykalsk
# Processing Record 28 of Set 10 | kano
# Processing Record 29 of Set 10 | coihaique
# Processing Record 30 of Set 10 | alberton
# Processing Record 31 of Set 10 | vangaindrano
# Processing Record 32 of Set 10 | bud
# Processing Record 33 of Set 10 | sergeyevka
# Processing Record 34 of Set 10 | valle de santiago
# Processing Record 35 of Set 10 | chara
# Processing Record 36 of Set 10 | vagur
# Processing Record 37 of Set 10 | santa cruz
# Processing Record 38 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 10 | beringovskiy
# Processing Record 40 of Set 10 | belmonte
# Processing Record 41 of Set 10 | nisia floresta
# Processing Record 42 of Set 10 | banda aceh
# Processing Record 43 of Set 10 | arequipa
# Processing Record 44 of Set 10 | sao paulo de olivenca
# Processing Record 45 of Set 10 | labuhan
# Processing Record 46 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 47 of Set 10 | flin flon
# Processing Record 48 of Set 10 | hambantota
# Processing Record 49 of Set 10 | shu
# Processing Record 50 of Set 10 | young
# Processing Record 1 of Set 11 | mestia
# Processing Record 2 of Set 11 | saquarema
# Processing Record 3 of Set 11 | nemuro
# Processing Record 4 of Set 11 | choix
# Processing Record 5 of Set 11 | ponta delgada
# Processing Record 6 of Set 11 | byron bay
# Processing Record 7 of Set 11 | ecublens
# Processing Record 8 of Set 11 | mushie
# Processing Record 9 of Set 11 | luwuk
# Processing Record 10 of Set 11 | road town
# Processing Record 11 of Set 11 | imbituba
# Processing Record 12 of Set 11 | ancud
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | udachnyy
# Processing Record 15 of Set 11 | manokwari
# Processing Record 16 of Set 11 | lerwick
# Processing Record 17 of Set 11 | taber
# Processing Record 18 of Set 11 | rawson
# Processing Record 19 of Set 11 | kaeo
# Processing Record 20 of Set 11 | oriximina
# Processing Record 21 of Set 11 | redcar
# Processing Record 22 of Set 11 | lumeje
# Processing Record 23 of Set 11 | mabaruma
# Processing Record 24 of Set 11 | ipeti
# City not found. Skipping...
# Processing Record 25 of Set 11 | san patricio
# Processing Record 26 of Set 11 | itarema
# Processing Record 27 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 11 | stokmarknes
# Processing Record 29 of Set 11 | kijang
# Processing Record 30 of Set 11 | lunglei
# Processing Record 31 of Set 11 | zhuanghe
# Processing Record 32 of Set 11 | zelenoborskiy
# Processing Record 33 of Set 11 | fond du lac
# Processing Record 34 of Set 11 | okhotsk
# Processing Record 35 of Set 11 | gabu
# Processing Record 36 of Set 11 | fare
# Processing Record 37 of Set 11 | gloucester
# Processing Record 38 of Set 11 | magnitka
# Processing Record 39 of Set 11 | kindu
# Processing Record 40 of Set 11 | palana
# Processing Record 41 of Set 11 | burnie
# Processing Record 42 of Set 11 | santa rosa
# Processing Record 43 of Set 11 | buta
# Processing Record 44 of Set 11 | andselv
# City not found. Skipping...
# Processing Record 45 of Set 11 | frontignan
# Processing Record 46 of Set 11 | gudiyattam
# City not found. Skipping...
# Processing Record 47 of Set 11 | malaya serdoba
# Processing Record 48 of Set 11 | palu
# Processing Record 49 of Set 11 | mangrol
# Processing Record 50 of Set 11 | saurimo
# Processing Record 1 of Set 12 | mbandaka
# Processing Record 2 of Set 12 | katangli
# Processing Record 3 of Set 12 | peniche
# Processing Record 4 of Set 12 | nurobod
# Processing Record 5 of Set 12 | soyo
# Processing Record 6 of Set 12 | rameshki
# Processing Record 7 of Set 12 | yulara
# Processing Record 8 of Set 12 | kalmunai
# Processing Record 9 of Set 12 | sinsheim
# Processing Record 10 of Set 12 | pontianak
# Processing Record 11 of Set 12 | karakose
# City not found. Skipping...
# Processing Record 12 of Set 12 | hwange
# Processing Record 13 of Set 12 | eyl
# Processing Record 14 of Set 12 | kilindoni
# Processing Record 15 of Set 12 | luanshya
# Processing Record 16 of Set 12 | bandiagara
# Processing Record 17 of Set 12 | santa isabel do rio negro
# Processing Record 18 of Set 12 | mattru
# Processing Record 19 of Set 12 | takob
# City not found. Skipping...
# Processing Record 20 of Set 12 | ust-kulom
# Processing Record 21 of Set 12 | tiznit
# Processing Record 22 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 12 | lakselv
# Processing Record 24 of Set 12 | kincardine
# Processing Record 25 of Set 12 | caapucu
# Processing Record 26 of Set 12 | medicine hat
# Processing Record 27 of Set 12 | ust-kan
# Processing Record 28 of Set 12 | bokoro
# Processing Record 29 of Set 12 | okha
# Processing Record 30 of Set 12 | port-cartier
# Processing Record 31 of Set 12 | roma
# Processing Record 32 of Set 12 | barra do garcas
# Processing Record 33 of Set 12 | ugoofaaru
# Processing Record 34 of Set 12 | haysville
# Processing Record 35 of Set 12 | inirida
# Processing Record 36 of Set 12 | maple creek
# Processing Record 37 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 38 of Set 12 | xai-xai
# Processing Record 39 of Set 12 | taonan
# Processing Record 40 of Set 12 | muisne
# Processing Record 41 of Set 12 | paita
# Processing Record 42 of Set 12 | jiuquan
# Processing Record 43 of Set 12 | xinyu
# Processing Record 44 of Set 12 | kingori
# Processing Record 45 of Set 12 | sumbe
# Processing Record 46 of Set 12 | awjilah
# Processing Record 47 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 48 of Set 12 | sawtell
# Processing Record 49 of Set 12 | mazamari
# Processing Record 50 of Set 12 | balasheyka
# Processing Record 1 of Set 13 | benguela
# Processing Record 2 of Set 13 | hunchun
# Processing Record 3 of Set 13 | tripoli
# Processing Record 4 of Set 13 | aras
# Processing Record 5 of Set 13 | zaysan
# Processing Record 6 of Set 13 | ilulissat
# Processing Record 7 of Set 13 | urfa
# City not found. Skipping...
# Processing Record 8 of Set 13 | shahganj
# Processing Record 9 of Set 13 | port said
# Processing Record 10 of Set 13 | lufilufi
# Processing Record 11 of Set 13 | nokaneng
# Processing Record 12 of Set 13 | fershampenuaz
# Processing Record 13 of Set 13 | miandrivazo
# Processing Record 14 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | godalming
# Processing Record 16 of Set 13 | tiarei
# Processing Record 17 of Set 13 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 18 of Set 13 | portland
# Processing Record 19 of Set 13 | gwadar
# Processing Record 20 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 21 of Set 13 | nusaybin
# Processing Record 22 of Set 13 | el prat de llobregat
# Processing Record 23 of Set 13 | doha
# Processing Record 24 of Set 13 | collie
# Processing Record 25 of Set 13 | meppel
# Processing Record 26 of Set 13 | juneau
# Processing Record 27 of Set 13 | tyler
# Processing Record 28 of Set 13 | gekhi
# Processing Record 29 of Set 13 | lodwar
# Processing Record 30 of Set 13 | haines junction
# Processing Record 31 of Set 13 | ipameri
# Processing Record 32 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 13 | trat
# Processing Record 34 of Set 13 | hakvik
# City not found. Skipping...
# Processing Record 35 of Set 13 | balvi
# Processing Record 36 of Set 13 | eldoret
# Processing Record 37 of Set 13 | kushima
# Processing Record 38 of Set 13 | paka
# Processing Record 39 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 40 of Set 13 | yerbogachen
# Processing Record 41 of Set 13 | ocos
# Processing Record 42 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 43 of Set 13 | norfolk
# Processing Record 44 of Set 13 | livingston
# Processing Record 45 of Set 13 | timizart
# Processing Record 46 of Set 13 | flinders
# Processing Record 47 of Set 13 | cairns
# Processing Record 48 of Set 13 | kutum
# Processing Record 49 of Set 13 | tabalosos
# Processing Record 50 of Set 13 | severodvinsk
# Processing Record 1 of Set 14 | tirumullaivasal
# Processing Record 2 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 14 | primorsk
# Processing Record 4 of Set 14 | benton harbor
# Processing Record 5 of Set 14 | jomalig
# City not found. Skipping...
# Processing Record 6 of Set 14 | grand gaube
# Processing Record 7 of Set 14 | grindavik
# Processing Record 8 of Set 14 | sao joao da barra
# Processing Record 9 of Set 14 | necochea
# Processing Record 10 of Set 14 | nyagan
# Processing Record 11 of Set 14 | astana
# Processing Record 12 of Set 14 | amapa
# Processing Record 13 of Set 14 | semirom
# Processing Record 14 of Set 14 | ritchie
# Processing Record 15 of Set 14 | san diego de la union
# Processing Record 16 of Set 14 | thunder bay
# Processing Record 17 of Set 14 | changping
# Processing Record 18 of Set 14 | gashua
# Processing Record 19 of Set 14 | camiri
# Processing Record 20 of Set 14 | bumba
# Processing Record 21 of Set 14 | bajil
# Processing Record 22 of Set 14 | bull savanna
# Processing Record 23 of Set 14 | achisay
# City not found. Skipping...
# Processing Record 24 of Set 14 | pakxan
# Processing Record 25 of Set 14 | abhar
# Processing Record 26 of Set 14 | mehamn
# Processing Record 27 of Set 14 | ahuimanu
# Processing Record 28 of Set 14 | puerto escondido
# Processing Record 29 of Set 14 | ellisras
# Processing Record 30 of Set 14 | balkhash
# Processing Record 31 of Set 14 | garden city
# Processing Record 32 of Set 14 | lokosovo
# Processing Record 33 of Set 14 | san cristobal
# Processing Record 34 of Set 14 | forrest city
# Processing Record 35 of Set 14 | asau
# Processing Record 36 of Set 14 | strezhevoy
# Processing Record 37 of Set 14 | jaguaribe
# Processing Record 38 of Set 14 | penzance
# Processing Record 39 of Set 14 | hirara
# Processing Record 40 of Set 14 | yeniseysk
# Processing Record 41 of Set 14 | hoopstad
# Processing Record 42 of Set 14 | san juan
# Processing Record 43 of Set 14 | knysna
# Processing Record 44 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 14 | huron
# Processing Record 46 of Set 14 | tabuk
# Processing Record 47 of Set 14 | saint-pierre
# Processing Record 48 of Set 14 | manthani
# Processing Record 49 of Set 14 | weligama
# Processing Record 50 of Set 14 | port hawkesbury
# Processing Record 1 of Set 15 | innisfail
# Processing Record 2 of Set 15 | cabedelo
# Processing Record 3 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 15 | cardston
# Processing Record 5 of Set 15 | jumla
# Processing Record 6 of Set 15 | kinablangan
# Processing Record 7 of Set 15 | shamary
# Processing Record 8 of Set 15 | atambua
# Processing Record 9 of Set 15 | nouakchott

# %%
len(city_data)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/adamp/OneDrive/Desktop/Bootcamp/Module 6 - APIs/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
